# %% [markdown]
# <a href="https://colab.research.google.com/github/patricio-tech/proyectos/blob/master/phase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clasificador de tipos de falla
# Redes neuronales convolucionales
#
# Edwin Solís
#
# 2020

# %% [markdown]
# ###RED NEURONAL CONVOLUCIONAL CLASIFICADOR

# %%
# !wget --no-check-certificate \
   https://www.dropbox.com/s/h2d2tvfu7c8tlf4/phase.zip?dl=0\
   -O /tmp/phase.zip
# Out:
# --2020-09-02 17:50:57--  https://www.dropbox.com/s/h2d2tvfu7c8tlf4/phase.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.1, 2620:100:6018:1::a27d:301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/h2d2tvfu7c8tlf4/phase.zip [following]
# --2020-09-02 17:50:57--  https://www.dropbox.com/s/raw/h2d2tvfu7c8tlf4/phase.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc71548029113ad6fa8a178cc56a.dl.dropboxusercontent.com/cd/0/inline/A-qw4AgRkXYrOqPgXbIsmfgtjraaODfB_c5KVskoXOGfWopvda0qw8mI9gFvLfGpQ0Wvp0-f1lECnfoEs9hdk4YLsG-jSnCyksTxXvLmVnYVwkbDc_wqocSpg7jmEx0I9Uk/file# [following]
# ...

# %%
import os
import zipfile

local_zip = '/tmp/phase.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
base_dir = '/tmp/phase'

train_dir =      os.path.join(base_dir, 'train')
#validation_dir = os.path.join(base_dir, 'validation')
test_dir =       os.path.join(base_dir, 'test')

# Directorio con las imagenes de training
train_ab_dir = os.path.join(train_dir, 'ab')
train_abc_dir = os.path.join(train_dir, 'abc')
train_abcn_dir = os.path.join(train_dir, 'abcn')
train_acn_dir = os.path.join(train_dir, 'acn')
train_an_dir = os.path.join(train_dir, 'an')
train_bc_dir = os.path.join(train_dir, 'bc')
train_bcn_dir = os.path.join(train_dir, 'bcn')
train_bn_dir = os.path.join(train_dir, 'bn')
train_cn_dir = os.path.join(train_dir, 'cn')


# Directorio con las imagenes de test
test_ab_dir = os.path.join(test_dir, 'ab')
test_abc_dir = os.path.join(test_dir, 'abc')
test_abcn_dir = os.path.join(test_dir, 'abcn')
test_acn_dir = os.path.join(test_dir, 'acn')
test_an_dir = os.path.join(test_dir, 'an')
test_bc_dir = os.path.join(test_dir, 'bc')
test_bcn_dir = os.path.join(test_dir, 'bcn')
test_bn_dir = os.path.join(test_dir, 'bn')
test_cn_dir = os.path.join(test_dir, 'cn')

# %%
train_ab_fnames = os.listdir( train_ab_dir )
print(train_ab_fnames[:5])
train_abc_fnames = os.listdir( train_abc_dir )
print(train_abc_fnames[:5])
train_abcn_fnames = os.listdir( train_abcn_dir )
print(train_abcn_fnames[:5])
train_acn_fnames = os.listdir( train_acn_dir )
print(train_acn_fnames[:5])
train_an_fnames = os.listdir( train_an_dir )
print(train_an_fnames[:5])
train_bc_fnames = os.listdir( train_bc_dir )
print(train_bc_fnames[:5])
train_bcn_fnames = os.listdir( train_bcn_dir )
print(train_bcn_fnames[:5])
train_bn_fnames = os.listdir( train_bn_dir )
print(train_bn_fnames[:5])
train_cn_fnames = os.listdir( train_cn_dir )
print(train_cn_fnames[:5])

test_ab_fnames = os.listdir( test_ab_dir )
print(test_ab_fnames[:5])
test_abc_fnames = os.listdir( test_abc_dir )
print(test_abc_fnames[:5])
test_abcn_fnames = os.listdir( test_abcn_dir )
print(test_abcn_fnames[:5])
test_acn_fnames = os.listdir( test_acn_dir )
print(test_acn_fnames[:5])
test_an_fnames = os.listdir( test_an_dir )
print(test_an_fnames[:5])
test_bc_fnames = os.listdir( test_bc_dir )
print(test_bc_fnames[:5])
test_bcn_fnames = os.listdir( test_bcn_dir )
print(test_bcn_fnames[:5])
test_bn_fnames = os.listdir( test_bn_dir )
print(test_bn_fnames[:5])
test_cn_fnames = os.listdir( test_cn_dir )
print(test_cn_fnames[:5])
# Out:
# ['faultab0.jpg', 'faultab1.jpg']
# ['faultabc0.jpg', 'faultabc2.jpg', 'faultabc1.jpg', 'faultabc3.jpg']
# ['faultabcn0.jpg', 'faultabcn3.jpg', 'faultabcn2.jpg', 'faultabcn4.jpg', 'faultabcn1.jpg']
# ['faultacn1.jpg', 'faultacn3.jpg', 'faultacn2.jpg', 'faultacn4.jpg', 'faultacn0.jpg']
# ['faultan3.jpg', 'faultan1.jpg', 'faultan4.jpg', 'faultan0.jpg', 'faultan2.jpg']
# ['faultbc4.jpg', 'faultbc1.jpg', 'faultbc3.jpg', 'faultbc0.jpg', 'faultbc2.jpg']
# ['faultbcn1.jpg', 'faultbcn0.jpg']
# ['faultbn1.jpg', 'faultbn3.jpg', 'faultbn2.jpg', 'faultbn0.jpg', 'faultbn4.jpg']
# ['faultcn9.jpg', 'faultcn14.jpg', 'faultcn0.jpg', 'faultcn15.jpg', 'faultcn10.jpg']
# ['faultab0.jpg', 'faultab1.jpg']
# ['faultabc0.jpg', 'faultabc4.jpg', 'faultabc2.jpg', 'faultabc1.jpg', 'faultabc3.jpg']
# ['faultabcn0.jpg', 'faultabcn3.jpg', 'faultabcn2.jpg', 'faultabcn4.jpg', 'faultabcn1.jpg']
# ['faultacn1.jpg', 'faultacn3.jpg', 'faultacn5.jpg', 'faultacn2.jpg', 'faultacn4.jpg']
# ...

# %%
print('total training ab images :', len(os.listdir(train_ab_dir ) ))
print('total training abc images :', len(os.listdir(train_abc_dir ) ))
print('total training abcn images :', len(os.listdir(train_abcn_dir ) ))
print('total training acn images :', len(os.listdir(train_acn_dir ) ))
print('total training an images :', len(os.listdir(train_an_dir ) ))
print('total training bc images :', len(os.listdir(train_bc_dir ) ))
print('total training bcn images :', len(os.listdir(train_bcn_dir ) ))
print('total training bn images :', len(os.listdir(train_bn_dir ) ))
print('total training cn images :', len(os.listdir(train_cn_dir ) ))

print('total test ab images :', len(os.listdir(test_ab_dir ) ))
print('total test abc images :', len(os.listdir(test_abc_dir ) ))
print('total test abcn images :', len(os.listdir(test_abcn_dir ) ))
print('total test acn images :', len(os.listdir(test_acn_dir ) ))
print('total test an images :', len(os.listdir(test_an_dir ) ))
print('total test bc images :', len(os.listdir(test_bc_dir ) ))
print('total test bcn images :', len(os.listdir(test_bcn_dir ) ))
print('total test bn images :', len(os.listdir(test_bn_dir ) ))
print('total test cn images :', len(os.listdir(test_cn_dir ) ))
# Out:
# total training ab images : 2
# total training abc images : 4
# total training abcn images : 5
# total training acn images : 5
# total training an images : 5
# total training bc images : 5
# total training bcn images : 2
# total training bn images : 5
# total training cn images : 16
# total test ab images : 2
# total test abc images : 5
# total test abcn images : 5
# total test acn images : 6
# total test an images : 5
# total test bc images : 5
# total test bcn images : 2
# total test bn images : 5
# total test cn images : 16

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows = 4
ncols = 4

pic_index = 0 # Índice para iterar sobre las imagenes

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_normal_pix = [os.path.join(train_cn_dir, fname)
                for fname in train_cn_fnames[ pic_index-8:pic_index]
]

for i, img_path in enumerate(next_normal_pix):
   sp = plt.subplot(nrows, ncols, i + 1)
   sp.axis('Off') # no imprimir ejes
   img = mpimg.imread(img_path)
   plt.imshow(img)

plt.show()

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# ...

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=1e-4),
   loss='categorical_crossentropy',
   metrics = ['acc']
   )

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator( rescale = 1.0/255. )
validation_datagen  = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                  batch_size=20,
                  class_mode='categorical',
                  target_size=(150, 150))

validation_generator = validation_datagen.flow_from_directory(test_dir,
                  batch_size=20,
                  class_mode = 'categorical',
                  target_size = (150, 150))

test_generator = test_datagen.flow_from_directory(test_dir,
                  batch_size=20,
                  class_mode = 'categorical',
                  target_size = (150, 150))
# Out:
# Found 49 images belonging to 9 classes.
# Found 51 images belonging to 9 classes.
# Found 51 images belonging to 9 classes.

# %%
batch_size = 20
steps_per_epoch = 2 #train_generator.n // batch_size
validation_steps = 1 #validation_generator.n // batch_size*2

print (steps_per_epoch)
print (validation_steps)
# Out:
# 2
# 1

# %%
history = model.fit_generator(
             train_generator,
             steps_per_epoch= steps_per_epoch,
             epochs=100,
             validation_data=validation_generator,
             validation_steps= validation_steps)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 637ms/step - loss: 1.8296 - acc: 0.8889 - val_loss: 1.7671 - val_acc: 0.8944
# Epoch 2/100
# 2/2 [==============================] - 1s 402ms/step - loss: 1.9599 - acc: 0.8851 - val_loss: 1.8259 - val_acc: 0.8889
# Epoch 3/100
# 2/2 [==============================] - 1s 620ms/step - loss: 1.7600 - acc: 0.8966 - val_loss: 2.0775 - val_acc: 0.8944
# Epoch 4/100
# 2/2 [==============================] - 1s 628ms/step - loss: 1.8960 - acc: 0.8966 - val_loss: 2.0225 - val_acc: 0.8889
# Epoch 5/100
# 2/2 [==============================] - 1s 402ms/step - loss: 1.8505 - acc: 0.8889 - val_loss: 2.0734 - val_acc: 0.8833
# Epoch 6/100
# 2/2 [==============================] - 1s 633ms/step - loss: 1.9115 - acc: 0.8889 - val_loss: 1.9145 - val_acc: 0.9000
# Epoch 7/100
# 2/2 [==============================] - 1s 614ms/step - loss: 1.9455 - acc: 0.8861 - val_loss: 2.0662 - val_acc: 0.8944
# Epoch 8/100
# ...

# %%
history_dict = history.history
print(history_dict.keys())
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
acc      = history.history[     'acc' ]
val_acc  = history.history[ 'val_acc' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(1,len(acc)+1,1)

plt.plot ( epochs,     acc, 'r--', label='Training acc'  )
plt.plot ( epochs, val_acc,  'b', label='Validation acc')
plt.title ('Training and validation accuracy')
plt.ylabel('acc')
plt.xlabel('epochs')

plt.legend()
plt.figure()

plt.plot ( epochs,     loss, 'r--' )
plt.plot ( epochs, val_loss ,  'b' )
plt.title ('Training and validation loss'   )
plt.ylabel('acc')
plt.xlabel('epochs')

plt.legend()
plt.figure()
# Out:
# No handles with labels found to put in legend.

# %%
test_lost, test_acc= model.evaluate_generator(test_generator)
print ("Test Accuracy:", test_acc)
# Out:
# Test Accuracy: 0.8823529481887817

# %%
out = model.predict_classes(test_generator)
print(out)
# Out:
# [2 6 6 8 8 8 2 8 2 4 8 8 3 6 8 6 8 8 6 2 8 2 8 8 2 4 7 8 7 7 3 8 8 2 8 2 8
#  8 6 6 3 8 8 8 8 4 8 8 5 7 8]
