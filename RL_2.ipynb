# %% [markdown]
# <a href="https://colab.research.google.com/github/patricio-tech/proyectos/blob/master/RL_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import torch
import torch.nn as nn

# %%
import gym
import gym.spaces

env = gym.make('FrozenLake-v0', is_slippery=False)

# %%
class OneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(OneHotWrapper, self).__init__(env)
        self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        r = np.copy(self.observation_space.low)
        r[observation] = 1.0
        return r

env = OneHotWrapper(env)

# %%
obs_size = env.observation_space.shape[0] # 16
n_actions = env.action_space.n  # 4
HIDDEN_SIZE = 32


net= nn.Sequential(
            nn.Linear(obs_size, HIDDEN_SIZE),
            nn.Sigmoid(),
            nn.Linear(HIDDEN_SIZE, n_actions)
        )

# %%
sm = nn.Softmax(dim=1)

def select_action(state):
        state_t = torch.FloatTensor([state])
        act_probs_t = sm(net(state_t))
        act_probs = act_probs_t.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        return action

# %%
import torch.optim as optim

objective = nn.CrossEntropyLoss()
optimizer = optim.Adam(params=net.parameters(), lr=0.001)

# %%
BATCH_SIZE = 100

GAMMA = 0.9

PERCENTILE = 30
REWARD_GOAL = 0.8

from collections import namedtuple

Episode = namedtuple('Episode', field_names=['reward', 'steps'])
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])

# %%
iter_no = 0
reward_mean = 0
full_batch = []
batch = []
episode_steps = []
episode_reward = 0.0
state = env.reset()
    
while reward_mean < REWARD_GOAL:
        action = select_action(state)
        next_state, reward, episode_is_done, _ = env.step(action)

        episode_steps.append(EpisodeStep(observation=state, action=action))
        episode_reward += reward
        
        if episode_is_done: # Episode finished            
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            next_state = env.reset()
            episode_steps = []
            episode_reward = 0.0
             
            if len(batch) == BATCH_SIZE: # New set of batches ready --> select "elite"
                reward_mean = float(np.mean(list(map(lambda s: s.reward, batch))))
                elite_candidates= batch 
                returnG = list(map(lambda s: s.reward * (GAMMA ** len(s.steps)), elite_candidates))
                reward_bound = np.percentile(returnG, PERCENTILE)

                train_obs = []
                train_act = []
                elite_batch = []
                for example, discounted_reward in zip(elite_candidates, returnG):
                        if discounted_reward > reward_bound:
                              train_obs.extend(map(lambda step: step.observation, example.steps))
                              train_act.extend(map(lambda step: step.action, example.steps))
                              elite_batch.append(example)
                full_batch=elite_batch
                state=train_obs
                acts=train_act

                
                if len(full_batch) != 0 : # just in case empty during an iteration
                 state_t = torch.FloatTensor(state)
                 acts_t = torch.LongTensor(acts)
                 optimizer.zero_grad()
                 action_scores_t = net(state_t)
                 loss_t = objective(action_scores_t, acts_t)
                 loss_t.backward()
                 optimizer.step()
                 print("%d: loss=%.3f, reward_mean=%.3f" % (iter_no, loss_t.item(), reward_mean))
                 iter_no += 1
                batch = []
        state = next_state
# Out:
# 0: loss=1.450, reward_mean=0.010
# 1: loss=1.410, reward_mean=0.010
# 2: loss=1.383, reward_mean=0.010
# 3: loss=1.453, reward_mean=0.010
# 4: loss=1.383, reward_mean=0.010
# 5: loss=1.376, reward_mean=0.030
# 6: loss=1.327, reward_mean=0.010
# 7: loss=1.374, reward_mean=0.020
# 8: loss=1.362, reward_mean=0.040
# 9: loss=1.371, reward_mean=0.030
# 10: loss=1.345, reward_mean=0.030
# 11: loss=1.377, reward_mean=0.030
# 12: loss=1.348, reward_mean=0.020
# 13: loss=1.357, reward_mean=0.030
# 14: loss=1.364, reward_mean=0.020
# 15: loss=1.321, reward_mean=0.010
# 16: loss=1.295, reward_mean=0.040
# 17: loss=1.356, reward_mean=0.010
# 18: loss=1.287, reward_mean=0.020
# 19: loss=1.366, reward_mean=0.040
# 20: loss=1.267, reward_mean=0.040
# 21: loss=1.239, reward_mean=0.020
# 22: loss=1.269, reward_mean=0.060
# 23: loss=1.314, reward_mean=0.020
# 24: loss=1.314, reward_mean=0.020
# 25: loss=1.206, reward_mean=0.020
# 26: loss=1.248, reward_mean=0.090
# 27: loss=1.326, reward_mean=0.010
# 28: loss=1.250, reward_mean=0.020
# 29: loss=1.274, reward_mean=0.020
# 30: loss=1.208, reward_mean=0.050
# 31: loss=1.311, reward_mean=0.020
# 32: loss=1.246, reward_mean=0.090
# 33: loss=1.202, reward_mean=0.030
# 34: loss=1.147, reward_mean=0.010
# 35: loss=1.226, reward_mean=0.030
# 36: loss=1.284, reward_mean=0.020
# 37: loss=1.241, reward_mean=0.040
# 38: loss=1.069, reward_mean=0.020
# 39: loss=1.239, reward_mean=0.080
# 40: loss=1.263, reward_mean=0.090
# 41: loss=1.181, reward_mean=0.100
# 42: loss=1.199, reward_mean=0.040
# 43: loss=1.131, reward_mean=0.030
# 44: loss=1.115, reward_mean=0.060
# 45: loss=1.164, reward_mean=0.070
# 46: loss=1.156, reward_mean=0.080
# 47: loss=1.162, reward_mean=0.060
# 48: loss=1.179, reward_mean=0.160
# 49: loss=1.098, reward_mean=0.070
# 50: loss=1.230, reward_mean=0.070
# 51: loss=1.148, reward_mean=0.080
# 52: loss=1.020, reward_mean=0.050
# 53: loss=1.209, reward_mean=0.090
# 54: loss=1.182, reward_mean=0.080
# 55: loss=1.065, reward_mean=0.100
# 56: loss=1.139, reward_mean=0.110
# 57: loss=1.225, reward_mean=0.040
# 58: loss=1.149, reward_mean=0.100
# 59: loss=1.137, reward_mean=0.080
# 60: loss=1.135, reward_mean=0.090
# 61: loss=1.192, reward_mean=0.110
# 62: loss=1.077, reward_mean=0.070
# 63: loss=1.063, reward_mean=0.080
# 64: loss=1.106, reward_mean=0.100
# 65: loss=1.134, reward_mean=0.100
# 66: loss=1.099, reward_mean=0.100
# 67: loss=1.151, reward_mean=0.130
# 68: loss=1.149, reward_mean=0.080
# 69: loss=1.015, reward_mean=0.110
# 70: loss=1.033, reward_mean=0.080
# 71: loss=1.086, reward_mean=0.140
# 72: loss=0.987, reward_mean=0.080
# 73: loss=1.116, reward_mean=0.130
# 74: loss=0.964, reward_mean=0.070
# 75: loss=1.096, reward_mean=0.110
# 76: loss=1.126, reward_mean=0.070
# 77: loss=1.135, reward_mean=0.160
# 78: loss=1.045, reward_mean=0.120
# 79: loss=1.005, reward_mean=0.130
# 80: loss=1.058, reward_mean=0.090
# 81: loss=1.084, reward_mean=0.070
# 82: loss=1.078, reward_mean=0.110
# 83: loss=1.029, reward_mean=0.130
# 84: loss=1.016, reward_mean=0.120
# 85: loss=0.969, reward_mean=0.120
# 86: loss=1.039, reward_mean=0.140
# 87: loss=1.061, reward_mean=0.120
# 88: loss=0.997, reward_mean=0.100
# 89: loss=1.090, reward_mean=0.120
# 90: loss=1.060, reward_mean=0.080
# 91: loss=1.056, reward_mean=0.120
# 92: loss=1.044, reward_mean=0.070
# 93: loss=0.970, reward_mean=0.120
# 94: loss=1.036, reward_mean=0.110
# 95: loss=0.971, reward_mean=0.100
# 96: loss=1.050, reward_mean=0.090
# 97: loss=0.980, reward_mean=0.130
# 98: loss=1.037, reward_mean=0.190
# 99: loss=1.062, reward_mean=0.110
# 100: loss=0.950, reward_mean=0.160
# 101: loss=0.959, reward_mean=0.180
# 102: loss=1.001, reward_mean=0.100
# 103: loss=0.946, reward_mean=0.150
# 104: loss=0.949, reward_mean=0.130
# 105: loss=0.905, reward_mean=0.110
# 106: loss=0.925, reward_mean=0.170
# 107: loss=1.002, reward_mean=0.120
# 108: loss=0.919, reward_mean=0.160
# 109: loss=0.924, reward_mean=0.070
# 110: loss=0.943, reward_mean=0.120
# 111: loss=0.990, reward_mean=0.150
# 112: loss=0.897, reward_mean=0.220
# 113: loss=1.000, reward_mean=0.120
# 114: loss=0.967, reward_mean=0.150
# 115: loss=0.942, reward_mean=0.110
# 116: loss=0.975, reward_mean=0.110
# 117: loss=0.981, reward_mean=0.130
# 118: loss=0.994, reward_mean=0.120
# 119: loss=0.951, reward_mean=0.050
# 120: loss=0.741, reward_mean=0.060
# 121: loss=0.919, reward_mean=0.120
# 122: loss=0.934, reward_mean=0.150
# 123: loss=0.975, reward_mean=0.150
# 124: loss=0.958, reward_mean=0.120
# 125: loss=0.923, reward_mean=0.110
# 126: loss=0.916, reward_mean=0.110
# 127: loss=0.857, reward_mean=0.100
# 128: loss=0.900, reward_mean=0.150
# 129: loss=0.933, reward_mean=0.150
# 130: loss=0.900, reward_mean=0.140
# 131: loss=0.935, reward_mean=0.150
# 132: loss=0.892, reward_mean=0.190
# 133: loss=0.806, reward_mean=0.120
# 134: loss=0.883, reward_mean=0.080
# 135: loss=0.844, reward_mean=0.180
# 136: loss=0.927, reward_mean=0.150
# 137: loss=0.844, reward_mean=0.150
# 138: loss=0.875, reward_mean=0.160
# 139: loss=0.819, reward_mean=0.170
# 140: loss=0.917, reward_mean=0.140
# 141: loss=0.908, reward_mean=0.160
# 142: loss=0.920, reward_mean=0.150
# 143: loss=0.913, reward_mean=0.140
# 144: loss=0.848, reward_mean=0.120
# 145: loss=0.946, reward_mean=0.110
# 146: loss=0.870, reward_mean=0.100
# 147: loss=0.862, reward_mean=0.180
# 148: loss=0.909, reward_mean=0.120
# 149: loss=0.947, reward_mean=0.160
# 150: loss=0.998, reward_mean=0.160
# 151: loss=0.816, reward_mean=0.110
# 152: loss=0.749, reward_mean=0.130
# 153: loss=0.909, reward_mean=0.090
# 154: loss=0.880, reward_mean=0.180
# 155: loss=0.904, reward_mean=0.170
# 156: loss=0.967, reward_mean=0.100
# 157: loss=0.870, reward_mean=0.170
# 158: loss=0.898, reward_mean=0.180
# 159: loss=0.880, reward_mean=0.120
# 160: loss=0.832, reward_mean=0.150
# 161: loss=0.898, reward_mean=0.160
# 162: loss=0.826, reward_mean=0.090
# 163: loss=0.883, reward_mean=0.200
# 164: loss=0.849, reward_mean=0.150
# 165: loss=0.821, reward_mean=0.210
# 166: loss=0.807, reward_mean=0.100
# 167: loss=0.807, reward_mean=0.220
# 168: loss=0.835, reward_mean=0.170
# 169: loss=0.747, reward_mean=0.100
# 170: loss=0.909, reward_mean=0.190
# 171: loss=0.881, reward_mean=0.140
# 172: loss=0.875, reward_mean=0.220
# 173: loss=0.816, reward_mean=0.160
# 174: loss=0.770, reward_mean=0.180
# 175: loss=0.824, reward_mean=0.210
# 176: loss=0.872, reward_mean=0.180
# 177: loss=0.826, reward_mean=0.200
# 178: loss=0.933, reward_mean=0.210
# 179: loss=0.741, reward_mean=0.170
# 180: loss=0.838, reward_mean=0.130
# 181: loss=0.724, reward_mean=0.150
# 182: loss=0.802, reward_mean=0.180
# 183: loss=0.862, reward_mean=0.170
# 184: loss=0.767, reward_mean=0.160
# 185: loss=0.766, reward_mean=0.190
# 186: loss=0.803, reward_mean=0.090
# 187: loss=0.790, reward_mean=0.180
# 188: loss=0.826, reward_mean=0.090
# 189: loss=0.735, reward_mean=0.160
# 190: loss=0.760, reward_mean=0.130
# 191: loss=0.820, reward_mean=0.160
# 192: loss=0.810, reward_mean=0.150
# 193: loss=0.919, reward_mean=0.150
# 194: loss=0.803, reward_mean=0.170
# 195: loss=0.773, reward_mean=0.140
# 196: loss=0.799, reward_mean=0.200
# 197: loss=0.728, reward_mean=0.170
# 198: loss=0.777, reward_mean=0.190
# 199: loss=0.765, reward_mean=0.150
# 200: loss=0.868, reward_mean=0.220
# 201: loss=0.789, reward_mean=0.230
# 202: loss=0.788, reward_mean=0.200
# 203: loss=0.703, reward_mean=0.140
# 204: loss=0.767, reward_mean=0.130
# 205: loss=0.881, reward_mean=0.140
# 206: loss=0.761, reward_mean=0.170
# 207: loss=0.770, reward_mean=0.150
# 208: loss=0.850, reward_mean=0.170
# 209: loss=0.736, reward_mean=0.140
# 210: loss=0.850, reward_mean=0.190
# 211: loss=0.749, reward_mean=0.150
# 212: loss=0.801, reward_mean=0.190
# 213: loss=0.790, reward_mean=0.170
# 214: loss=0.870, reward_mean=0.200
# 215: loss=0.725, reward_mean=0.180
# 216: loss=0.876, reward_mean=0.100
# 217: loss=0.850, reward_mean=0.180
# 218: loss=0.834, reward_mean=0.150
# 219: loss=0.899, reward_mean=0.200
# 220: loss=0.677, reward_mean=0.230
# 221: loss=0.771, reward_mean=0.250
# 222: loss=0.772, reward_mean=0.140
# 223: loss=0.715, reward_mean=0.210
# 224: loss=0.734, reward_mean=0.230
# 225: loss=0.804, reward_mean=0.240
# 226: loss=0.797, reward_mean=0.160
# 227: loss=0.799, reward_mean=0.260
# 228: loss=0.701, reward_mean=0.210
# 229: loss=0.797, reward_mean=0.180
# 230: loss=0.842, reward_mean=0.210
# 231: loss=0.726, reward_mean=0.200
# 232: loss=0.794, reward_mean=0.250
# 233: loss=0.751, reward_mean=0.190
# 234: loss=0.680, reward_mean=0.250
# 235: loss=0.724, reward_mean=0.110
# 236: loss=0.727, reward_mean=0.140
# 237: loss=0.803, reward_mean=0.240
# 238: loss=0.892, reward_mean=0.140
# 239: loss=0.767, reward_mean=0.190
# 240: loss=0.716, reward_mean=0.240
# 241: loss=0.746, reward_mean=0.220
# 242: loss=0.839, reward_mean=0.200
# 243: loss=0.706, reward_mean=0.210
# 244: loss=0.794, reward_mean=0.210
# 245: loss=0.728, reward_mean=0.220
# 246: loss=0.746, reward_mean=0.130
# 247: loss=0.735, reward_mean=0.180
# 248: loss=0.774, reward_mean=0.220
# 249: loss=0.727, reward_mean=0.270
# 250: loss=0.733, reward_mean=0.190
# 251: loss=0.768, reward_mean=0.170
# 252: loss=0.782, reward_mean=0.160
# 253: loss=0.700, reward_mean=0.170
# 254: loss=0.753, reward_mean=0.180
# 255: loss=0.742, reward_mean=0.260
# 256: loss=0.830, reward_mean=0.190
# 257: loss=0.684, reward_mean=0.200
# 258: loss=0.925, reward_mean=0.150
# 259: loss=0.750, reward_mean=0.220
# 260: loss=0.704, reward_mean=0.270
# 261: loss=0.739, reward_mean=0.210
# 262: loss=0.728, reward_mean=0.160
# 263: loss=0.737, reward_mean=0.220
# 264: loss=0.742, reward_mean=0.310
# 265: loss=0.645, reward_mean=0.150
# 266: loss=0.734, reward_mean=0.190
# 267: loss=0.810, reward_mean=0.220
# 268: loss=0.741, reward_mean=0.210
# 269: loss=0.724, reward_mean=0.230
# 270: loss=0.822, reward_mean=0.260
# 271: loss=0.753, reward_mean=0.170
# 272: loss=0.835, reward_mean=0.160
# 273: loss=0.715, reward_mean=0.250
# 274: loss=0.745, reward_mean=0.220
# 275: loss=0.733, reward_mean=0.250
# 276: loss=0.800, reward_mean=0.200
# 277: loss=0.762, reward_mean=0.170
# 278: loss=0.706, reward_mean=0.240
# 279: loss=0.728, reward_mean=0.200
# 280: loss=0.754, reward_mean=0.230
# 281: loss=0.699, reward_mean=0.220
# 282: loss=0.768, reward_mean=0.250
# 283: loss=0.717, reward_mean=0.270
# 284: loss=0.728, reward_mean=0.220
# 285: loss=0.720, reward_mean=0.190
# 286: loss=0.733, reward_mean=0.240
# 287: loss=0.685, reward_mean=0.250
# 288: loss=0.743, reward_mean=0.200
# 289: loss=0.715, reward_mean=0.220
# 290: loss=0.710, reward_mean=0.240
# 291: loss=0.691, reward_mean=0.210
# 292: loss=0.764, reward_mean=0.240
# 293: loss=0.707, reward_mean=0.220
# 294: loss=0.719, reward_mean=0.240
# 295: loss=0.751, reward_mean=0.220
# 296: loss=0.824, reward_mean=0.160
# 297: loss=0.659, reward_mean=0.260
# 298: loss=0.722, reward_mean=0.220
# 299: loss=0.693, reward_mean=0.280
# 300: loss=0.718, reward_mean=0.200
# 301: loss=0.726, reward_mean=0.210
# 302: loss=0.654, reward_mean=0.300
# 303: loss=0.691, reward_mean=0.170
# 304: loss=0.696, reward_mean=0.220
# 305: loss=0.693, reward_mean=0.190
# 306: loss=0.690, reward_mean=0.200
# 307: loss=0.755, reward_mean=0.240
# 308: loss=0.678, reward_mean=0.260
# 309: loss=0.711, reward_mean=0.140
# 310: loss=0.717, reward_mean=0.250
# 311: loss=0.675, reward_mean=0.280
# 312: loss=0.703, reward_mean=0.300
# 313: loss=0.809, reward_mean=0.250
# 314: loss=0.695, reward_mean=0.180
# 315: loss=0.715, reward_mean=0.220
# 316: loss=0.658, reward_mean=0.240
# 317: loss=0.659, reward_mean=0.180
# 318: loss=0.700, reward_mean=0.210
# 319: loss=0.704, reward_mean=0.180
# 320: loss=0.746, reward_mean=0.300
# 321: loss=0.705, reward_mean=0.280
# 322: loss=0.667, reward_mean=0.220
# 323: loss=0.634, reward_mean=0.190
# 324: loss=0.659, reward_mean=0.210
# 325: loss=0.695, reward_mean=0.230
# 326: loss=0.645, reward_mean=0.230
# 327: loss=0.663, reward_mean=0.310
# 328: loss=0.729, reward_mean=0.280
# 329: loss=0.694, reward_mean=0.300
# 330: loss=0.702, reward_mean=0.270
# 331: loss=0.677, reward_mean=0.290
# 332: loss=0.698, reward_mean=0.270
# 333: loss=0.698, reward_mean=0.290
# 334: loss=0.659, reward_mean=0.240
# 335: loss=0.665, reward_mean=0.240
# 336: loss=0.676, reward_mean=0.330
# 337: loss=0.676, reward_mean=0.290
# 338: loss=0.630, reward_mean=0.240
# 339: loss=0.691, reward_mean=0.220
# 340: loss=0.717, reward_mean=0.250
# 341: loss=0.700, reward_mean=0.220
# 342: loss=0.694, reward_mean=0.300
# 343: loss=0.625, reward_mean=0.230
# 344: loss=0.675, reward_mean=0.250
# 345: loss=0.686, reward_mean=0.330
# 346: loss=0.664, reward_mean=0.280
# 347: loss=0.646, reward_mean=0.240
# 348: loss=0.694, reward_mean=0.340
# 349: loss=0.607, reward_mean=0.240
# 350: loss=0.665, reward_mean=0.350
# 351: loss=0.675, reward_mean=0.200
# 352: loss=0.714, reward_mean=0.240
# 353: loss=0.619, reward_mean=0.340
# 354: loss=0.686, reward_mean=0.320
# 355: loss=0.728, reward_mean=0.270
# 356: loss=0.704, reward_mean=0.230
# 357: loss=0.677, reward_mean=0.270
# 358: loss=0.628, reward_mean=0.260
# 359: loss=0.673, reward_mean=0.280
# 360: loss=0.666, reward_mean=0.280
# 361: loss=0.684, reward_mean=0.200
# 362: loss=0.599, reward_mean=0.400
# 363: loss=0.670, reward_mean=0.230
# 364: loss=0.684, reward_mean=0.320
# 365: loss=0.680, reward_mean=0.240
# 366: loss=0.692, reward_mean=0.270
# 367: loss=0.666, reward_mean=0.320
# 368: loss=0.643, reward_mean=0.340
# 369: loss=0.677, reward_mean=0.300
# 370: loss=0.654, reward_mean=0.270
# 371: loss=0.667, reward_mean=0.270
# 372: loss=0.666, reward_mean=0.310
# 373: loss=0.650, reward_mean=0.250
# 374: loss=0.681, reward_mean=0.340
# 375: loss=0.639, reward_mean=0.290
# 376: loss=0.726, reward_mean=0.330
# 377: loss=0.672, reward_mean=0.420
# 378: loss=0.690, reward_mean=0.310
# 379: loss=0.682, reward_mean=0.370
# 380: loss=0.707, reward_mean=0.320
# 381: loss=0.614, reward_mean=0.230
# 382: loss=0.711, reward_mean=0.310
# 383: loss=0.604, reward_mean=0.400
# 384: loss=0.662, reward_mean=0.280
# 385: loss=0.669, reward_mean=0.290
# 386: loss=0.620, reward_mean=0.390
# 387: loss=0.697, reward_mean=0.250
# 388: loss=0.673, reward_mean=0.310
# 389: loss=0.674, reward_mean=0.290
# 390: loss=0.646, reward_mean=0.340
# 391: loss=0.622, reward_mean=0.310
# 392: loss=0.681, reward_mean=0.360
# 393: loss=0.612, reward_mean=0.300
# 394: loss=0.655, reward_mean=0.390
# 395: loss=0.607, reward_mean=0.310
# 396: loss=0.630, reward_mean=0.340
# 397: loss=0.654, reward_mean=0.280
# 398: loss=0.638, reward_mean=0.260
# 399: loss=0.704, reward_mean=0.350
# 400: loss=0.664, reward_mean=0.360
# 401: loss=0.621, reward_mean=0.250
# 402: loss=0.612, reward_mean=0.320
# 403: loss=0.633, reward_mean=0.350
# 404: loss=0.679, reward_mean=0.400
# 405: loss=0.620, reward_mean=0.350
# 406: loss=0.627, reward_mean=0.410
# 407: loss=0.663, reward_mean=0.350
# 408: loss=0.656, reward_mean=0.300
# 409: loss=0.685, reward_mean=0.350
# 410: loss=0.660, reward_mean=0.280
# 411: loss=0.609, reward_mean=0.310
# 412: loss=0.643, reward_mean=0.300
# 413: loss=0.679, reward_mean=0.380
# 414: loss=0.612, reward_mean=0.410
# 415: loss=0.643, reward_mean=0.370
# 416: loss=0.631, reward_mean=0.370
# 417: loss=0.645, reward_mean=0.390
# 418: loss=0.613, reward_mean=0.390
# 419: loss=0.581, reward_mean=0.320
# 420: loss=0.666, reward_mean=0.370
# 421: loss=0.652, reward_mean=0.400
# 422: loss=0.696, reward_mean=0.290
# 423: loss=0.621, reward_mean=0.350
# 424: loss=0.602, reward_mean=0.360
# 425: loss=0.633, reward_mean=0.360
# 426: loss=0.613, reward_mean=0.330
# 427: loss=0.674, reward_mean=0.370
# 428: loss=0.643, reward_mean=0.490
# 429: loss=0.584, reward_mean=0.340
# 430: loss=0.605, reward_mean=0.340
# 431: loss=0.627, reward_mean=0.340
# 432: loss=0.645, reward_mean=0.370
# 433: loss=0.678, reward_mean=0.360
# 434: loss=0.638, reward_mean=0.380
# 435: loss=0.631, reward_mean=0.390
# 436: loss=0.619, reward_mean=0.400
# 437: loss=0.581, reward_mean=0.400
# 438: loss=0.661, reward_mean=0.360
# 439: loss=0.633, reward_mean=0.310
# 440: loss=0.601, reward_mean=0.330
# 441: loss=0.636, reward_mean=0.370
# 442: loss=0.689, reward_mean=0.410
# 443: loss=0.614, reward_mean=0.390
# 444: loss=0.620, reward_mean=0.330
# 445: loss=0.583, reward_mean=0.390
# 446: loss=0.591, reward_mean=0.430
# 447: loss=0.632, reward_mean=0.380
# 448: loss=0.619, reward_mean=0.420
# 449: loss=0.610, reward_mean=0.460
# 450: loss=0.636, reward_mean=0.390
# 451: loss=0.633, reward_mean=0.300
# 452: loss=0.602, reward_mean=0.310
# 453: loss=0.584, reward_mean=0.340
# 454: loss=0.630, reward_mean=0.350
# 455: loss=0.599, reward_mean=0.340
# 456: loss=0.586, reward_mean=0.480
# 457: loss=0.612, reward_mean=0.380
# 458: loss=0.593, reward_mean=0.440
# 459: loss=0.584, reward_mean=0.330
# 460: loss=0.641, reward_mean=0.410
# 461: loss=0.583, reward_mean=0.390
# 462: loss=0.607, reward_mean=0.400
# 463: loss=0.567, reward_mean=0.420
# 464: loss=0.577, reward_mean=0.440
# 465: loss=0.604, reward_mean=0.430
# 466: loss=0.649, reward_mean=0.460
# 467: loss=0.585, reward_mean=0.380
# 468: loss=0.590, reward_mean=0.380
# 469: loss=0.632, reward_mean=0.380
# 470: loss=0.576, reward_mean=0.360
# 471: loss=0.600, reward_mean=0.420
# 472: loss=0.609, reward_mean=0.410
# 473: loss=0.586, reward_mean=0.480
# 474: loss=0.603, reward_mean=0.420
# 475: loss=0.585, reward_mean=0.420
# 476: loss=0.573, reward_mean=0.350
# 477: loss=0.578, reward_mean=0.460
# 478: loss=0.605, reward_mean=0.480
# 479: loss=0.580, reward_mean=0.510
# 480: loss=0.582, reward_mean=0.390
# 481: loss=0.583, reward_mean=0.410
# 482: loss=0.567, reward_mean=0.430
# 483: loss=0.588, reward_mean=0.420
# 484: loss=0.618, reward_mean=0.420
# 485: loss=0.616, reward_mean=0.450
# 486: loss=0.564, reward_mean=0.420
# 487: loss=0.594, reward_mean=0.510
# 488: loss=0.604, reward_mean=0.460
# 489: loss=0.569, reward_mean=0.490
# 490: loss=0.550, reward_mean=0.500
# 491: loss=0.581, reward_mean=0.450
# 492: loss=0.571, reward_mean=0.560
# 493: loss=0.567, reward_mean=0.400
# 494: loss=0.573, reward_mean=0.490
# 495: loss=0.585, reward_mean=0.480
# 496: loss=0.575, reward_mean=0.510
# 497: loss=0.602, reward_mean=0.460
# 498: loss=0.581, reward_mean=0.440
# 499: loss=0.588, reward_mean=0.460
# 500: loss=0.546, reward_mean=0.400
# 501: loss=0.613, reward_mean=0.390
# 502: loss=0.606, reward_mean=0.410
# 503: loss=0.524, reward_mean=0.430
# 504: loss=0.618, reward_mean=0.460
# 505: loss=0.577, reward_mean=0.470
# 506: loss=0.560, reward_mean=0.480
# 507: loss=0.570, reward_mean=0.440
# 508: loss=0.556, reward_mean=0.480
# 509: loss=0.594, reward_mean=0.420
# 510: loss=0.611, reward_mean=0.500
# 511: loss=0.541, reward_mean=0.510
# 512: loss=0.553, reward_mean=0.540
# 513: loss=0.576, reward_mean=0.480
# 514: loss=0.549, reward_mean=0.460
# 515: loss=0.542, reward_mean=0.450
# 516: loss=0.546, reward_mean=0.540
# 517: loss=0.589, reward_mean=0.490
# 518: loss=0.597, reward_mean=0.510
# 519: loss=0.582, reward_mean=0.470
# 520: loss=0.620, reward_mean=0.600
# 521: loss=0.580, reward_mean=0.500
# 522: loss=0.570, reward_mean=0.470
# 523: loss=0.607, reward_mean=0.380
# 524: loss=0.615, reward_mean=0.550
# 525: loss=0.573, reward_mean=0.430
# 526: loss=0.569, reward_mean=0.510
# 527: loss=0.574, reward_mean=0.550
# 528: loss=0.561, reward_mean=0.580
# 529: loss=0.575, reward_mean=0.530
# 530: loss=0.530, reward_mean=0.570
# 531: loss=0.562, reward_mean=0.500
# 532: loss=0.574, reward_mean=0.540
# 533: loss=0.564, reward_mean=0.530
# 534: loss=0.548, reward_mean=0.510
# 535: loss=0.560, reward_mean=0.580
# 536: loss=0.591, reward_mean=0.510
# 537: loss=0.536, reward_mean=0.580
# 538: loss=0.557, reward_mean=0.560
# 539: loss=0.581, reward_mean=0.530
# 540: loss=0.551, reward_mean=0.520
# 541: loss=0.549, reward_mean=0.510
# 542: loss=0.556, reward_mean=0.510
# 543: loss=0.543, reward_mean=0.510
# 544: loss=0.540, reward_mean=0.510
# 545: loss=0.600, reward_mean=0.520
# 546: loss=0.573, reward_mean=0.460
# 547: loss=0.540, reward_mean=0.590
# 548: loss=0.547, reward_mean=0.580
# 549: loss=0.543, reward_mean=0.450
# 550: loss=0.559, reward_mean=0.490
# 551: loss=0.535, reward_mean=0.500
# 552: loss=0.553, reward_mean=0.540
# 553: loss=0.563, reward_mean=0.610
# 554: loss=0.542, reward_mean=0.550
# 555: loss=0.544, reward_mean=0.570
# 556: loss=0.564, reward_mean=0.550
# 557: loss=0.536, reward_mean=0.540
# 558: loss=0.584, reward_mean=0.550
# 559: loss=0.552, reward_mean=0.590
# 560: loss=0.552, reward_mean=0.600
# 561: loss=0.539, reward_mean=0.550
# 562: loss=0.519, reward_mean=0.560
# 563: loss=0.591, reward_mean=0.630
# 564: loss=0.522, reward_mean=0.560
# 565: loss=0.593, reward_mean=0.620
# 566: loss=0.551, reward_mean=0.600
# 567: loss=0.540, reward_mean=0.620
# 568: loss=0.618, reward_mean=0.560
# 569: loss=0.547, reward_mean=0.560
# 570: loss=0.568, reward_mean=0.700
# 571: loss=0.516, reward_mean=0.540
# 572: loss=0.538, reward_mean=0.570
# 573: loss=0.591, reward_mean=0.560
# 574: loss=0.546, reward_mean=0.600
# 575: loss=0.531, reward_mean=0.610
# 576: loss=0.544, reward_mean=0.670
# 577: loss=0.531, reward_mean=0.600
# 578: loss=0.559, reward_mean=0.570
# 579: loss=0.545, reward_mean=0.600
# 580: loss=0.556, reward_mean=0.700
# 581: loss=0.521, reward_mean=0.640
# 582: loss=0.533, reward_mean=0.650
# 583: loss=0.536, reward_mean=0.610
# 584: loss=0.528, reward_mean=0.710
# 585: loss=0.547, reward_mean=0.660
# 586: loss=0.518, reward_mean=0.580
# 587: loss=0.520, reward_mean=0.550
# 588: loss=0.515, reward_mean=0.600
# 589: loss=0.546, reward_mean=0.670
# 590: loss=0.512, reward_mean=0.680
# 591: loss=0.562, reward_mean=0.660
# 592: loss=0.535, reward_mean=0.600
# 593: loss=0.507, reward_mean=0.590
# 594: loss=0.558, reward_mean=0.630
# 595: loss=0.547, reward_mean=0.560
# 596: loss=0.522, reward_mean=0.680
# 597: loss=0.523, reward_mean=0.540
# 598: loss=0.533, reward_mean=0.620
# 599: loss=0.502, reward_mean=0.620
# 600: loss=0.552, reward_mean=0.670
# 601: loss=0.518, reward_mean=0.620
# 602: loss=0.520, reward_mean=0.620
# 603: loss=0.522, reward_mean=0.670
# 604: loss=0.523, reward_mean=0.590
# 605: loss=0.531, reward_mean=0.610
# 606: loss=0.520, reward_mean=0.700
# 607: loss=0.529, reward_mean=0.590
# 608: loss=0.520, reward_mean=0.660
# 609: loss=0.530, reward_mean=0.670
# 610: loss=0.505, reward_mean=0.760
# 611: loss=0.557, reward_mean=0.640
# 612: loss=0.529, reward_mean=0.680
# 613: loss=0.541, reward_mean=0.670
# 614: loss=0.532, reward_mean=0.660
# 615: loss=0.488, reward_mean=0.670
# 616: loss=0.534, reward_mean=0.640
# 617: loss=0.515, reward_mean=0.680
# 618: loss=0.568, reward_mean=0.630
# 619: loss=0.534, reward_mean=0.700
# 620: loss=0.534, reward_mean=0.610
# 621: loss=0.540, reward_mean=0.660
# 622: loss=0.558, reward_mean=0.660
# 623: loss=0.506, reward_mean=0.680
# 624: loss=0.512, reward_mean=0.660
# 625: loss=0.542, reward_mean=0.720
# 626: loss=0.483, reward_mean=0.720
# 627: loss=0.530, reward_mean=0.710
# 628: loss=0.543, reward_mean=0.660
# 629: loss=0.513, reward_mean=0.680
# 630: loss=0.530, reward_mean=0.650
# 631: loss=0.494, reward_mean=0.700
# 632: loss=0.508, reward_mean=0.700
# 633: loss=0.518, reward_mean=0.700
# 634: loss=0.498, reward_mean=0.750
# 635: loss=0.553, reward_mean=0.650
# 636: loss=0.495, reward_mean=0.710
# 637: loss=0.522, reward_mean=0.680
# 638: loss=0.509, reward_mean=0.790
# 639: loss=0.563, reward_mean=0.690
# 640: loss=0.510, reward_mean=0.620
# 641: loss=0.488, reward_mean=0.760
# 642: loss=0.546, reward_mean=0.670
# 643: loss=0.549, reward_mean=0.640
# 644: loss=0.513, reward_mean=0.680
# 645: loss=0.547, reward_mean=0.660
# 646: loss=0.507, reward_mean=0.640
# 647: loss=0.488, reward_mean=0.690
# 648: loss=0.485, reward_mean=0.710
# 649: loss=0.523, reward_mean=0.680
# 650: loss=0.543, reward_mean=0.660
# 651: loss=0.522, reward_mean=0.650
# 652: loss=0.511, reward_mean=0.700
# 653: loss=0.498, reward_mean=0.620
# 654: loss=0.561, reward_mean=0.710
# 655: loss=0.529, reward_mean=0.690
# 656: loss=0.550, reward_mean=0.670
# 657: loss=0.531, reward_mean=0.680
# 658: loss=0.517, reward_mean=0.760
# 659: loss=0.480, reward_mean=0.750
# 660: loss=0.500, reward_mean=0.670
# 661: loss=0.480, reward_mean=0.820

# %%
test_env = OneHotWrapper(gym.make('FrozenLake-v0', is_slippery=False))
state= test_env.reset()
test_env.render()

is_done = False

while not is_done:
    action = select_action(state)
    new_state, reward, is_done, _ = test_env.step(action)
    test_env.render()
    state = new_state

print("reward = ", reward)
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# reward =  0.0
